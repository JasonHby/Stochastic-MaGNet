# %% [markdown]
# # Train Stochastic Magnet version 1
# ### Usage
# 1. Upload files (train.py, tool.py, Dataset.py, Magnetv1.py, MaGNet.py, MAGE.py, F2DAttn.py, S2DAttn.py, Hypergraph.py, my_nas100_2025_data.pt) into Google Colab, using the "folder" icon on the left tool bar.
# 2. Train using T4 GPU
# 3. Save the .pt files for future reference. Or run the last cell to automatically save all resulting files.
#
#
#
# ### The output files
# | File | Description |
# |---|---|
# | `best_model_Magnetv1.pth` | Model weights from the epoch with highest validation accuracy. Use this for inference. |
# | `final_model_Magnetv1.pth` | Model weights from the last epoch before early stopping. Fallback if best model underperforms. |
# | `training_history_Magnetv1.pt` | Dict of per-epoch metrics (loss, accuracy, F1, AUROC, AUPRC) for train/val/test splits. Load with `torch.load()` to compare runs or regenerate plots. |
# | `training_history_Magnetv1.png` | Training curves chart (loss, accuracy, precision, recall, F1, AUROC, AUPRC). |
# | `mc_results_Magnetv1.pt` | MC Dropout uncertainty results on the test set. Contains `mean_pred` [N×2] (direction probabilities averaged over 100 stochastic forward passes) <br> and `var_pred` [N×2] (variance across those 100 passes — higher = less confident). Use to filter predictions by confidence before trading. |
#
# <br>
# <br>
# <br>

# %%
# !pip install torcheval transformers
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from torcheval) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %%
# !python train.py
# Out:
# Using device: cuda
# Loading and preprocessing data...
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py:1334: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   super().__init__("GRU", *args, **kwargs)
# Starting training...
#
# Epoch 1/30
# Training: 100% 35/35 [00:48<00:00,  1.38s/it, loss=0.676, accuracy=0.597, precision=0.535, recall=0.569, f1=0.551, auroc=0.628, auprc=0.546]
# New best model saved with validation accuracy: 0.4664
# Train - Loss: 0.6998, accuracy: 0.5012, precision: 0.5221, recall: 0.5269, f1: 0.5244, auroc: 0.4994, auprc: 0.5217,
# Valid - Loss: 0.7067, accuracy: 0.4664, precision: 0.5057, recall: 0.4317, f1: 0.4658, auroc: 0.4655, auprc: 0.5317,
# Test - Loss: 0.6972, accuracy: 0.5160, precision: 0.5512, recall: 0.3676, f1: 0.4411, auroc: 0.5187, auprc: 0.5484,
#
# Epoch 2/30
# Training: 100% 35/35 [00:46<00:00,  1.32s/it, loss=0.695, accuracy=0.504, precision=0.549, recall=0.455, f1=0.498, auroc=0.524, auprc=0.577]
# Train - Loss: 0.6996, accuracy: 0.5036, precision: 0.5241, recall: 0.5338, f1: 0.5289, auroc: 0.5047, auprc: 0.5285,
# Valid - Loss: 0.7086, accuracy: 0.4353, precision: 0.4742, recall: 0.4409, f1: 0.4569, auroc: 0.4503, auprc: 0.5242,
# Test - Loss: 0.6958, accuracy: 0.5055, precision: 0.5328, recall: 0.3898, f1: 0.4503, auroc: 0.5234, auprc: 0.5520,
#
# Epoch 3/30
# Training: 100% 35/35 [00:45<00:00,  1.31s/it, loss=0.699, accuracy=0.497, precision=0.44, recall=0.62, f1=0.515, auroc=0.515, auprc=0.429]
# Train - Loss: 0.7016, accuracy: 0.4988, precision: 0.5189, recall: 0.5480, f1: 0.5331, auroc: 0.4928, auprc: 0.5138,
# Valid - Loss: 0.7087, accuracy: 0.4597, precision: 0.4985, recall: 0.4555, f1: 0.4760, auroc: 0.4415, auprc: 0.5139,
# Test - Loss: 0.6971, accuracy: 0.4925, precision: 0.5150, recall: 0.3967, f1: 0.4481, auroc: 0.5123, auprc: 0.5404,
#
# Epoch 4/30
# Training: 100% 35/35 [00:45<00:00,  1.29s/it, loss=0.712, accuracy=0.485, precision=0.51, recall=0.645, f1=0.57, auroc=0.428, auprc=0.467]
# Train - Loss: 0.6989, accuracy: 0.5094, precision: 0.5282, recall: 0.5647, f1: 0.5458, auroc: 0.5063, auprc: 0.5244,
# Valid - Loss: 0.7088, accuracy: 0.4630, precision: 0.5016, recall: 0.5062, f1: 0.5039, auroc: 0.4443, auprc: 0.5175,
# Test - Loss: 0.6959, accuracy: 0.5147, precision: 0.5367, recall: 0.4815, f1: 0.5076, auroc: 0.5191, auprc: 0.5460,
#
# Epoch 5/30
# Training: 100% 35/35 [00:45<00:00,  1.29s/it, loss=0.711, accuracy=0.501, precision=0.453, recall=0.846, f1=0.59, auroc=0.53, auprc=0.426]
# Train - Loss: 0.7004, accuracy: 0.5024, precision: 0.5205, recall: 0.5915, f1: 0.5538, auroc: 0.4972, auprc: 0.5203,
# Valid - Loss: 0.7086, accuracy: 0.4472, precision: 0.4859, recall: 0.4482, f1: 0.4663, auroc: 0.4456, auprc: 0.5085,
# Test - Loss: 0.6952, accuracy: 0.5029, precision: 0.5233, recall: 0.4831, f1: 0.5024, auroc: 0.5220, auprc: 0.5511,
#
# Epoch 6/30
# Training: 100% 35/35 [00:44<00:00,  1.28s/it, loss=0.724, accuracy=0.411, precision=0.444, recall=0.492, f1=0.467, auroc=0.378, auprc=0.46]
# New best model saved with validation accuracy: 0.4677
# Train - Loss: 0.6986, accuracy: 0.5048, precision: 0.5220, recall: 0.6084, f1: 0.5619, auroc: 0.5032, auprc: 0.5278,
# Valid - Loss: 0.7022, accuracy: 0.4677, precision: 0.5057, recall: 0.5357, f1: 0.5203, auroc: 0.4648, auprc: 0.5361,
# Test - Loss: 0.6962, accuracy: 0.4985, precision: 0.5189, recall: 0.4740, f1: 0.4954, auroc: 0.5082, auprc: 0.5310,
#
# Epoch 7/30
# Training: 100% 35/35 [00:45<00:00,  1.30s/it, loss=0.7, accuracy=0.499, precision=0.543, recall=0.613, f1=0.576, auroc=0.465, auprc=0.533]
# New best model saved with validation accuracy: 0.4854
# Train - Loss: 0.6956, accuracy: 0.5136, precision: 0.5287, recall: 0.6270, f1: 0.5737, auroc: 0.5144, auprc: 0.5399,
# Valid - Loss: 0.7016, accuracy: 0.4854, precision: 0.5279, recall: 0.4240, f1: 0.4703, auroc: 0.4785, auprc: 0.5376,
# Test - Loss: 0.6962, accuracy: 0.4981, precision: 0.5198, recall: 0.4432, f1: 0.4785, auroc: 0.5133, auprc: 0.5314,
#
# Epoch 8/30
# Training: 100% 35/35 [00:45<00:00,  1.30s/it, loss=0.711, accuracy=0.449, precision=0.402, recall=0.591, f1=0.479, auroc=0.439, auprc=0.384]
# New best model saved with validation accuracy: 0.4893
# Train - Loss: 0.6996, accuracy: 0.4987, precision: 0.5177, recall: 0.5812, f1: 0.5476, auroc: 0.4924, auprc: 0.5150,
# Valid - Loss: 0.6980, accuracy: 0.4893, precision: 0.5252, recall: 0.5447, f1: 0.5347, auroc: 0.4871, auprc: 0.5440,
# Test - Loss: 0.6950, accuracy: 0.5119, precision: 0.5280, recall: 0.5697, f1: 0.5481, auroc: 0.5194, auprc: 0.5340,
#
# Epoch 9/30
# Training: 100% 35/35 [00:45<00:00,  1.30s/it, loss=0.691, accuracy=0.545, precision=0.596, recall=0.542, f1=0.567, auroc=0.55, auprc=0.579]
# New best model saved with validation accuracy: 0.5128
# Train - Loss: 0.6969, accuracy: 0.5087, precision: 0.5245, recall: 0.6281, f1: 0.5717, auroc: 0.5051, auprc: 0.5228,
# Valid - Loss: 0.6948, accuracy: 0.5128, precision: 0.5437, recall: 0.5952, f1: 0.5683, auroc: 0.5119, auprc: 0.5517,
# Test - Loss: 0.6980, accuracy: 0.5005, precision: 0.5186, recall: 0.5369, f1: 0.5276, auroc: 0.4913, auprc: 0.5135,
#
# Epoch 10/30
# Training: 100% 35/35 [00:45<00:00,  1.29s/it, loss=0.697, accuracy=0.493, precision=0.569, recall=0.579, f1=0.574, auroc=0.48, auprc=0.609]
# Train - Loss: 0.6962, accuracy: 0.5143, precision: 0.5272, recall: 0.6741, f1: 0.5917, auroc: 0.5089, auprc: 0.5257,
# Valid - Loss: 0.6972, accuracy: 0.5103, precision: 0.5343, recall: 0.7105, f1: 0.6099, auroc: 0.4928, auprc: 0.5361,
# Test - Loss: 0.6944, accuracy: 0.5035, precision: 0.5184, recall: 0.6221, f1: 0.5656, auroc: 0.5054, auprc: 0.5359,
#
# Epoch 11/30
# Training: 100% 35/35 [00:45<00:00,  1.30s/it, loss=0.691, accuracy=0.536, precision=0.511, recall=0.743, f1=0.605, auroc=0.556, auprc=0.52]
# Train - Loss: 0.6974, accuracy: 0.5029, precision: 0.5185, recall: 0.6701, f1: 0.5846, auroc: 0.4958, auprc: 0.5201,
# Valid - Loss: 0.6976, accuracy: 0.4779, precision: 0.5115, recall: 0.6889, f1: 0.5871, auroc: 0.4728, auprc: 0.5320,
# Test - Loss: 0.6953, accuracy: 0.5079, precision: 0.5242, recall: 0.5719, f1: 0.5470, auroc: 0.5061, auprc: 0.5309,
#
# Epoch 12/30
# Training: 100% 35/35 [00:45<00:00,  1.30s/it, loss=0.696, accuracy=0.515, precision=0.52, recall=0.88, f1=0.654, auroc=0.524, auprc=0.526]
# New best model saved with validation accuracy: 0.5200
# Train - Loss: 0.6965, accuracy: 0.5031, precision: 0.5209, recall: 0.5987, f1: 0.5571, auroc: 0.5000, auprc: 0.5235,
# Valid - Loss: 0.6963, accuracy: 0.5200, precision: 0.5381, recall: 0.7713, f1: 0.6339, auroc: 0.4801, auprc: 0.5343,
# Test - Loss: 0.6922, accuracy: 0.5251, precision: 0.5347, recall: 0.6623, f1: 0.5917, auroc: 0.5306, auprc: 0.5466,
#
# Epoch 13/30
# Training: 100% 35/35 [00:45<00:00,  1.30s/it, loss=0.699, accuracy=0.496, precision=0.478, recall=0.77, f1=0.59, auroc=0.527, auprc=0.495]
# Train - Loss: 0.6973, accuracy: 0.5090, precision: 0.5211, recall: 0.7328, f1: 0.6091, auroc: 0.4984, auprc: 0.5196,
# Valid - Loss: 0.7009, accuracy: 0.4993, precision: 0.5240, recall: 0.7715, f1: 0.6241, auroc: 0.4588, auprc: 0.5080,
# Test - Loss: 0.6948, accuracy: 0.5163, precision: 0.5231, recall: 0.7806, f1: 0.6264, auroc: 0.5197, auprc: 0.5313,
#
# Epoch 14/30
# Training: 100% 35/35 [00:45<00:00,  1.31s/it, loss=0.707, accuracy=0.476, precision=0.432, recall=0.653, f1=0.52, auroc=0.482, auprc=0.415]
# Train - Loss: 0.6957, accuracy: 0.5143, precision: 0.5254, recall: 0.7184, f1: 0.6069, auroc: 0.5063, auprc: 0.5248,
# Valid - Loss: 0.6969, accuracy: 0.4744, precision: 0.5100, recall: 0.6249, f1: 0.5616, auroc: 0.4653, auprc: 0.5283,
# Test - Loss: 0.6921, accuracy: 0.5211, precision: 0.5295, recall: 0.7020, f1: 0.6037, auroc: 0.5247, auprc: 0.5481,
# Early stopping triggered
# Figure saved to training_history.png
# Figure(1600x800)
# Saved: training_history.pt, final_model.pth, best_model.pth, training_history.png
# Training completed!
# Best validation accuracy: 0.5200

# %%
# !python inference_MC.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py:1334: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   super().__init__("GRU", *args, **kwargs)
# Running MC Dropout inference...
#   MC run 10/100
#   MC run 20/100
#   MC run 30/100
#   MC run 40/100
#   MC run 50/100
#   MC run 60/100
#   MC run 70/100
#   MC run 80/100
#   MC run 90/100
#   MC run 100/100
# mean_pred shape: torch.Size([21390, 2])
# var_pred shape: torch.Size([21390, 2])
# Saved to mc_results.pt

# %%
# Save the resulting files (You can also save manually in the left "folder" bar)
from google.colab import files
files.download('best_model.pth')
files.download('final_model.pth')
files.download('training_history.pt')
files.download('training_history.png')
files.download('mc_results.pt')
